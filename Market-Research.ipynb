# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
city_df = pd.read_csv('MarketHealthIndex_City.csv')

# %%
city_df.head()
# Out:
#   RegionType    RegionName          City State  \
# 0       City      New York      New York    NY
# 1       City   Los Angeles   Los Angeles    CA
# 2       City       Chicago       Chicago    IL
# 3       City       Houston       Houston    TX
# 4       City  Philadelphia  Philadelphia    PA
#
#                                 Metro  \
# 0                        New York, NY
# 1  Los Angeles-Long Beach-Anaheim, CA
# 2                         Chicago, IL
# 3                         Houston, TX
# 4                    Philadelphia, PA
#
#                                        CBSATitle  SizeRank  MarketHealthIndex  \
# 0        "New York-Newark-Jersey City, NY-NJ-PA"         0           9.496971
# 1           "Los Angeles-Long Beach-Anaheim, CA"         1           6.636681
# 2           "Chicago-Naperville-Elgin, IL-IN-WI"         2           3.939783
# 3         "Houston-The Woodlands-Sugar Land, TX"         3           7.593171
# ...

# %%
mo_df = city_df[city_df.Metro == 'St. Louis, MO']
co_df = city_df[city_df.Metro == 'Denver, CO']

# %%
mo_df.head()
# Out:
#     RegionType     RegionName           City State          Metro  \
# 53        City    Saint Louis    Saint Louis    MO  St. Louis, MO
# 520       City  Saint Charles  Saint Charles    MO  St. Louis, MO
# 575       City       O Fallon       O Fallon    MO  St. Louis, MO
# 723       City   Saint Peters   Saint Peters    MO  St. Louis, MO
# 812       City     Florissant     Florissant    MO  St. Louis, MO
#
#               CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 53   "St. Louis, MO-IL"        53           1.746833        69.46
# 520  "St. Louis, MO-IL"       521           6.136405        75.00
# 575  "St. Louis, MO-IL"       576           6.287865        75.71
# 723  "St. Louis, MO-IL"       726           4.183037        69.77
# 812  "St. Louis, MO-IL"       817           1.275014        74.07
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM       YoY  \
# 53          11.1958            7.4280   99400  0.404040  4.192872
# ...

# %%
mo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 53 to 10871
# Data columns (total 19 columns):
# RegionType              161 non-null object
# RegionName              161 non-null object
# City                    161 non-null object
# State                   161 non-null object
# Metro                   161 non-null object
# CBSATitle               161 non-null object
# SizeRank                151 non-null float64
# MarketHealthIndex       161 non-null float64
# SellForGain             112 non-null float64
# PrevForeclosed          40 non-null float64
# ForeclosureRatio        85 non-null float64
# ZHVI                    151 non-null float64
# MoM                     151 non-null float64
# YoY                     151 non-null float64
# ForecastYoYPctChange    151 non-null float64
# StockOfREOs             151 non-null float64
# NegativeEquity          117 non-null float64
# Delinquency             117 non-null float64
# DaysOnMarket            161 non-null float64
# ...

# %%
mo_df.State.unique()
# Out:
# array(['MO', 'IL'], dtype=object)

# %%
#sns.factorplot('City', data = mo_df, hue='State')
mo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 53 to 10871
# Data columns (total 19 columns):
# RegionType              161 non-null object
# RegionName              161 non-null object
# City                    161 non-null object
# State                   161 non-null object
# Metro                   161 non-null object
# CBSATitle               161 non-null object
# SizeRank                151 non-null float64
# MarketHealthIndex       161 non-null float64
# SellForGain             112 non-null float64
# PrevForeclosed          40 non-null float64
# ForeclosureRatio        85 non-null float64
# ZHVI                    151 non-null float64
# MoM                     151 non-null float64
# YoY                     151 non-null float64
# ForecastYoYPctChange    151 non-null float64
# StockOfREOs             151 non-null float64
# NegativeEquity          117 non-null float64
# Delinquency             117 non-null float64
# DaysOnMarket            161 non-null float64
# ...

# %%
sns.countplot('RegionName', data= mo_df)

# %%
mo_df.head()
# Out:
#     RegionType     RegionName           City State          Metro  \
# 53        City    Saint Louis    Saint Louis    MO  St. Louis, MO
# 520       City  Saint Charles  Saint Charles    MO  St. Louis, MO
# 575       City       O Fallon       O Fallon    MO  St. Louis, MO
# 723       City   Saint Peters   Saint Peters    MO  St. Louis, MO
# 812       City     Florissant     Florissant    MO  St. Louis, MO
#
#               CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 53   "St. Louis, MO-IL"        53           1.746833        69.46
# 520  "St. Louis, MO-IL"       521           6.136405        75.00
# 575  "St. Louis, MO-IL"       576           6.287865        75.71
# 723  "St. Louis, MO-IL"       726           4.183037        69.77
# 812  "St. Louis, MO-IL"       817           1.275014        74.07
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM       YoY  \
# 53          11.1958            7.4280   99400  0.404040  4.192872
# ...

# %%
mo_df.MarketHealthIndex.hist(bins=10)

# %%
co_df.MarketHealthIndex.hist(bins=10)

# %%
mo_df.head()
# Out:
#     RegionType     RegionName           City State          Metro  \
# 53        City    Saint Louis    Saint Louis    MO  St. Louis, MO
# 520       City  Saint Charles  Saint Charles    MO  St. Louis, MO
# 575       City       O Fallon       O Fallon    MO  St. Louis, MO
# 723       City   Saint Peters   Saint Peters    MO  St. Louis, MO
# 812       City     Florissant     Florissant    MO  St. Louis, MO
#
#               CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 53   "St. Louis, MO-IL"        53           1.746833        69.46
# 520  "St. Louis, MO-IL"       521           6.136405        75.00
# 575  "St. Louis, MO-IL"       576           6.287865        75.71
# 723  "St. Louis, MO-IL"       726           4.183037        69.77
# 812  "St. Louis, MO-IL"       817           1.275014        74.07
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM       YoY  \
# 53          11.1958            7.4280   99400  0.404040  4.192872
# ...

# %%
co_df.head()
# Out:
#     RegionType   RegionName         City State       Metro  \
# 22        City       Denver       Denver    CO  Denver, CO
# 52        City       Aurora       Aurora    CO  Denver, CO
# 180       City     Lakewood     Lakewood    CO  Denver, CO
# 253       City     Thornton     Thornton    CO  Denver, CO
# 255       City  Westminster  Westminster    CO  Denver, CO
#
#                         CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 22   "Denver-Aurora-Lakewood, CO"        22           9.757665        97.14
# 52   "Denver-Aurora-Lakewood, CO"        52           9.359280        96.63
# 180  "Denver-Aurora-Lakewood, CO"       180           9.657610        99.48
# 253  "Denver-Aurora-Lakewood, CO"       253           9.494217        98.41
# 255  "Denver-Aurora-Lakewood, CO"       255           9.769598        96.00
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM        YoY  \
# 22           2.4739            0.6771  326200  1.053284  16.666667
# ...

# %% [markdown]
# mo_df.ZHVI.hist(bins=70)

# %%
mo_df.ZHVI.hist(bins=70)

# %%
co_df.ZHVI.hist(bins=70)

# %%
mo_df.DaysOnMarket.describe()
# Out:
# count    161.000000
# mean      88.618012
# std       17.603934
# min       56.500000
# 25%       74.000000
# 50%       84.000000
# 75%      103.000000
# max      124.000000
# Name: DaysOnMarket, dtype: float64

# %%
co_df.DaysOnMarket.describe()
# Out:
# count     57.000000
# mean      58.421053
# std       11.932021
# min       47.000000
# 25%       52.000000
# 50%       54.000000
# 75%       63.500000
# max      101.000000
# Name: DaysOnMarket, dtype: float64

# %%
frame = [co_df, mo_df]

# %%
comp_df = pd.concat(frame)

# %%
sns.distplot(comp_df.MarketHealthIndex, bins=10)

# %%
sns.countplot('Metro', data=comp_df)

# %%
sns.countplot('State', data=comp_df)

# %%
comp_df.head()
# Out:
#     RegionType   RegionName         City State       Metro  \
# 22        City       Denver       Denver    CO  Denver, CO
# 52        City       Aurora       Aurora    CO  Denver, CO
# 180       City     Lakewood     Lakewood    CO  Denver, CO
# 253       City     Thornton     Thornton    CO  Denver, CO
# 255       City  Westminster  Westminster    CO  Denver, CO
#
#                         CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 22   "Denver-Aurora-Lakewood, CO"        22           9.757665        97.14
# 52   "Denver-Aurora-Lakewood, CO"        52           9.359280        96.63
# 180  "Denver-Aurora-Lakewood, CO"       180           9.657610        99.48
# 253  "Denver-Aurora-Lakewood, CO"       253           9.494217        98.41
# 255  "Denver-Aurora-Lakewood, CO"       255           9.769598        96.00
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM        YoY  \
# 22           2.4739            0.6771  326200  1.053284  16.666667
# ...

# %%
fig = sns.FacetGrid(comp_df,hue='Metro',aspect=4)
fig.map(sns.kdeplot, 'MarketHealthIndex',shade=True)

# %%
fig = sns.FacetGrid(comp_df,hue='Metro',aspect=4)
fig.map(sns.kdeplot, 'SellForGain',shade=True)
fig.add_legend()

# %%
fig = sns.FacetGrid(comp_df,hue='Metro',aspect=4)
fig.map(sns.kdeplot, 'ForeclosureRatio',shade=True)
fig.add_legend()
maxval = comp_df.ForeclosureRatio.max()
print maxval
fig.set(xlim=(0,20))
# Out:
# 99.0426

# %%
# Out:
# count    109.000000
# mean       9.893052
# std       14.846892
# min        0.172100
# 25%        2.138800
# 50%        4.829300
# 75%       12.315300
# max       99.042600
# Name: ForeclosureRatio, dtype: float64

# %%
o9comp_df = comp_df[comp_df.MarketHealthIndex > 9]

# %%
o9comp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 22 to 9695
# Data columns (total 19 columns):
# RegionType              47 non-null object
# RegionName              47 non-null object
# City                    47 non-null object
# State                   47 non-null object
# Metro                   47 non-null object
# CBSATitle               47 non-null object
# SizeRank                47 non-null float64
# MarketHealthIndex       47 non-null float64
# SellForGain             45 non-null float64
# PrevForeclosed          28 non-null float64
# ForeclosureRatio        26 non-null float64
# ZHVI                    47 non-null float64
# MoM                     47 non-null float64
# YoY                     47 non-null float64
# ForecastYoYPctChange    47 non-null float64
# StockOfREOs             47 non-null float64
# NegativeEquity          40 non-null float64
# Delinquency             40 non-null float64
# DaysOnMarket            47 non-null float64
# ...

# %%
o9comp_df.head()
# Out:
#     RegionType   RegionName         City State       Metro  \
# 22        City       Denver       Denver    CO  Denver, CO
# 52        City       Aurora       Aurora    CO  Denver, CO
# 180       City     Lakewood     Lakewood    CO  Denver, CO
# 253       City     Thornton     Thornton    CO  Denver, CO
# 255       City  Westminster  Westminster    CO  Denver, CO
#
#                         CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 22   "Denver-Aurora-Lakewood, CO"        22           9.757665        97.14
# 52   "Denver-Aurora-Lakewood, CO"        52           9.359280        96.63
# 180  "Denver-Aurora-Lakewood, CO"       180           9.657610        99.48
# 253  "Denver-Aurora-Lakewood, CO"       253           9.494217        98.41
# 255  "Denver-Aurora-Lakewood, CO"       255           9.769598        96.00
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM        YoY  \
# 22           2.4739            0.6771  326200  1.053284  16.666667
# ...

# %%
o9comp_df = o9comp_df.drop('RegionType',1)

# %%
sns.countplot('CBSATitle', data=o9comp_df)

# %%
o9comp_df = o9comp_df.drop(['RegionName','CBSATitle'],1)

# %%
o9comp_df.head()
# Out:
#             City State       Metro  SizeRank  MarketHealthIndex  SellForGain  \
# 22        Denver    CO  Denver, CO        22           9.757665        97.14
# 52        Aurora    CO  Denver, CO        52           9.359280        96.63
# 180     Lakewood    CO  Denver, CO       180           9.657610        99.48
# 253     Thornton    CO  Denver, CO       253           9.494217        98.41
# 255  Westminster    CO  Denver, CO       255           9.769598        96.00
#
#      PrevForeclosed  ForeclosureRatio    ZHVI       MoM        YoY  \
# 22           2.4739            0.6771  326200  1.053284  16.666667
# 52           4.4683            1.5971  234400  1.559792  20.328542
# 180          3.6692            0.8443  311200  1.302083  15.515961
# 253          2.3483            0.6997  270900  1.006711  15.868263
# 255          2.8733            0.4466  277300  1.204380  15.493544
#
#      ForecastYoYPctChange  StockOfREOs  NegativeEquity  Delinquency  \
# ...

# %%
o9comp_df.sort_values(by='ForecastYoYPctChange', ascending=0)
# Out:
#                     City State          Metro  SizeRank  MarketHealthIndex  \
# 10648            Bennett    CO     Denver, CO     10974           9.643841
# 52                Aurora    CO     Denver, CO        52           9.359280
# 5637            Sheridan    CO     Denver, CO      5693           9.353773
# 2868         Sherrelwood    CO     Denver, CO      2891           9.697081
# 7585               Byers    CO     Denver, CO      7712           9.321645
# 7939               Derby    CO     Denver, CO      8088           9.306958
# 1329           Englewood    CO     Denver, CO      1337           9.750321
# 1241       Commerce City    CO     Denver, CO      1248           9.295943
# 1355          Northglenn    CO     Denver, CO      1363           9.519919
# 1122           Littleton    CO     Denver, CO      1129           9.811823
# 3525           Elizabeth    CO     Denver, CO      3553           9.806315
# ...

# %%
city_df[city_df.City == 'Longmont']
# Out:
#     RegionType RegionName      City State        Metro      CBSATitle  \
# 461       City   Longmont  Longmont    CO  Boulder, CO  "Boulder, CO"
#
#      SizeRank  MarketHealthIndex  SellForGain  PrevForeclosed  \
# 461       461            9.59978        97.44          2.1741
#
#      ForeclosureRatio    ZHVI       MoM        YoY  ForecastYoYPctChange  \
# 461            0.6329  289200  1.260504  15.403033              0.034423
#
#      StockOfREOs  NegativeEquity  Delinquency  DaysOnMarket
# 461         40.9        0.063615     0.004648            50

# %%
city_df.head()
# Out:
#   RegionType    RegionName          City State  \
# 0       City      New York      New York    NY
# 1       City   Los Angeles   Los Angeles    CA
# 2       City       Chicago       Chicago    IL
# 3       City       Houston       Houston    TX
# 4       City  Philadelphia  Philadelphia    PA
#
#                                 Metro  \
# 0                        New York, NY
# 1  Los Angeles-Long Beach-Anaheim, CA
# 2                         Chicago, IL
# 3                         Houston, TX
# 4                    Philadelphia, PA
#
#                                        CBSATitle  SizeRank  MarketHealthIndex  \
# 0        "New York-Newark-Jersey City, NY-NJ-PA"         0           9.496971
# 1           "Los Angeles-Long Beach-Anaheim, CA"         1           6.636681
# 2           "Chicago-Naperville-Elgin, IL-IN-WI"         2           3.939783
# 3         "Houston-The Woodlands-Sugar Land, TX"         3           7.593171
# ...

# %%
state_df = city_df[(city_df.State == 'CO')| (city_df.State == 'MO')]

# %%
city_df.sort_values(by = 'ForecastYoYPctChange', ascending = 0)
# Out:
#       RegionType              RegionName                    City State  \
# 6036        City                Sardinia                Sardinia    OH
# 9378        City             Hamersville             Hamersville    OH
# 9018        City               Lexington               Lexington    GA
# 7505        City              Clyde Hill              Clyde Hill    WA
# 5830        City              Mount Orab              Mount Orab    OH
# 9646        City                Crawford                Crawford    GA
# 2483        City              Greenfield              Greenfield    CA
# 67          City                Stockton                Stockton    CA
# 7292        City         Lincoln Village         Lincoln Village    CA
# 2096        City                 Brawley                 Brawley    CA
# 10074       City              Maidsville              Maidsville    WV
# 3239        City                 Escalon                 Escalon    CA
# ...

# %%
state_df.head()
# Out:
#    RegionType        RegionName              City State                 Metro  \
# 22       City            Denver            Denver    CO            Denver, CO
# 35       City       Kansas City       Kansas City    MO       Kansas City, MO
# 37       City  Colorado Springs  Colorado Springs    CO  Colorado Springs, CO
# 52       City            Aurora            Aurora    CO            Denver, CO
# 53       City       Saint Louis       Saint Louis    MO         St. Louis, MO
#
#                        CBSATitle  SizeRank  MarketHealthIndex  SellForGain  \
# 22  "Denver-Aurora-Lakewood, CO"        22           9.757665        97.14
# 35          "Kansas City, MO-KS"        35           3.423903        75.71
# 37        "Colorado Springs, CO"        37           6.965302        88.24
# 52  "Denver-Aurora-Lakewood, CO"        52           9.359280        96.63
# 53            "St. Louis, MO-IL"        53           1.746833        69.46
#
# ...

# %%
state_df = state_df.drop(['RegionType', 'RegionName','CBSATitle'], 1)

# %%
state_df.head()
# Out:
#                 City State                 Metro  SizeRank  MarketHealthIndex  \
# 22            Denver    CO            Denver, CO        22           9.757665
# 35       Kansas City    MO       Kansas City, MO        35           3.423903
# 37  Colorado Springs    CO  Colorado Springs, CO        37           6.965302
# 52            Aurora    CO            Denver, CO        52           9.359280
# 53       Saint Louis    MO         St. Louis, MO        53           1.746833
#
#     SellForGain  PrevForeclosed  ForeclosureRatio    ZHVI       MoM  \
# 22        97.14          2.4739            0.6771  326200  1.053284
# 35        75.71             NaN               NaN  104900  0.382775
# 37        88.24          4.0548            2.9340  217000  0.556070
# 52        96.63          4.4683            1.5971  234400  1.559792
# 53        69.46         11.1958            7.4280   99400  0.404040
#
#           YoY  ForecastYoYPctChange  StockOfREOs  NegativeEquity  Delinquency  \
# ...

# %%
state_df = state_df[state_df['MarketHealthIndex'] > 8.5]

# %%
sns.distplot(state_df['YoY'], bins=100)

# %%
state_df[state_df['YoY'] == state_df['YoY'].max()]
# Out:
#           City State       Metro  SizeRank  MarketHealthIndex  SellForGain  \
# 5637  Sheridan    CO  Denver, CO      5693           9.353773          100
#
#       PrevForeclosed  ForeclosureRatio    ZHVI       MoM        YoY  \
# 5637             NaN               NaN  216400  2.123643  23.375143
#
#       ForecastYoYPctChange  StockOfREOs  NegativeEquity  Delinquency  \
# 5637              0.068128         51.1             NaN          NaN
#
#       DaysOnMarket
# 5637            52

# %%
mo_state_df = state_df[(state_df['State'] == 'MO')].sort_values('MoM',ascending = 0)

# %%
sns.lmplot('MarketHealthIndex', 'YoY', data=mo_state_df)

# %%
sns.lmplot('MarketHealthIndex','YoY',data=mo_state_df, x_bins=[9,9.1,9.2,9.3,9.4,9.5,9.6,9.7,9.8,9.9,10])

# %%
mo_state_df[mo_state_df.YoY > 10]
# Out:
#               City State            Metro  SizeRank  MarketHealthIndex  \
# 9610     Lone Jack    MO  Kansas City, MO      9870           9.400587
# 9639    Winchester    MO    St. Louis, MO      9899           8.740591
# 10732  Garden City    MO  Kansas City, MO     11063           9.385900
# 6400     Frontenac    MO    St. Louis, MO      6475           9.439141
#
#        SellForGain  PrevForeclosed  ForeclosureRatio    ZHVI       MoM  \
# 9610           100             NaN               NaN  205600  2.085402
# 9639           NaN             NaN            8.8968  133700  1.595745
# 10732          NaN             NaN               NaN  102800  1.480750
# 6400           100             NaN               NaN  722900  0.794757
#
#              YoY  ForecastYoYPctChange  StockOfREOs  NegativeEquity  \
# 9610   15.700619              0.067670         89.0        0.103604
# 9639   10.954357              0.027809         13.7             NaN
# ...

# %%
sns.lmplot('MarketHealthIndex','ForecastYoYPctChange',data=mo_state_df)

# %%
sns.lmplot('MarketHealthIndex','ZHVI',data=mo_state_df)

# %%
sns.lmplot('ForecastYoYPctChange','ZHVI',data=mo_state_df, aspect=2)

# %%
mo_state_df[mo_state_df['ForecastYoYPctChange']<0.04]
# Out:
#                 City State          Metro  SizeRank  MarketHealthIndex  \
# 9639      Winchester    MO  St. Louis, MO      9899           8.740591
# 2455      Manchester    MO  St. Louis, MO      2474           9.281256
# 1887  Webster Groves    MO  St. Louis, MO      1897           9.098586
# 2512         Concord    MO  St. Louis, MO      2531           9.357444
# 1413         Ballwin    MO  St. Louis, MO      1421           9.250964
# 9407    Warson Woods    MO  St. Louis, MO      9654           8.704792
# 1206        Oakville    MO  St. Louis, MO      1213           8.828713
# 1673        Kirkwood    MO  St. Louis, MO      1683           8.847990
# 3993           Ladue    MO  St. Louis, MO      4024           9.203231
# 2318     Creve Coeur    MO  St. Louis, MO      2336           8.564347
# 1004    Chesterfield    MO  St. Louis, MO      1011           9.753993
#
#       SellForGain  PrevForeclosed  ForeclosureRatio    ZHVI       MoM  \
# ...
